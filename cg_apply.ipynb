# %%
# %load_ext autoreload
# %autoreload 2

from concept_gradient_v2 import ConceptGradients

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification
import torch.nn.functional as F
import torch.nn as nn
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import torch
import os
from datasets import Dataset
from concept_gradient_v2 import ConceptGradients
from torch.utils.data import DataLoader

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

class X2YModel(nn.Module):
    def __init__(self, model_name='./saved_target_model', num_classes=2):
        super(X2YModel, self).__init__()
        self.model = RobertaForSequenceClassification.from_pretrained(model_name, num_labels=num_classes)
        
    def forward(self, input_ids=None, attention_mask=None, inputs_embeds=None):
        if inputs_embeds is not None:
            outputs = self.model.roberta(inputs_embeds=inputs_embeds, attention_mask=attention_mask)
        else:
            outputs = self.model.roberta(input_ids=input_ids, attention_mask=attention_mask)
        
        return self.model.classifier(outputs.last_hidden_state)  


class X2CModel(nn.Module):
    def __init__(self, model_name='./saved_concept_model', num_concepts=5):
        super(X2CModel, self).__init__()
        self.model = RobertaForSequenceClassification.from_pretrained(model_name, num_labels=num_concepts, ignore_mismatched_sizes=True).to('cuda')

    def forward(self, input_ids=None, attention_mask=None, inputs_embeds=None):
        if inputs_embeds is not None:
            outputs = self.model.roberta(inputs_embeds=inputs_embeds, attention_mask=attention_mask)
        else:
            outputs = self.model.roberta(input_ids=input_ids, attention_mask=attention_mask)
        
        return self.model.classifier(outputs.last_hidden_state)

x2y_model = X2YModel().to(device)
x2c_model = X2CModel().to(device)

# %%
def forward_func(embeddings, attention_mask):
    output = x2y_model(inputs_embeds=embeddings, attention_mask=attention_mask)
    return output

def concept_forward_func(embeddings, attention_mask):
    output = x2c_model(inputs_embeds=embeddings, attention_mask=attention_mask)
    return output

# %%
cg = ConceptGradients(forward_func, concept_forward_func=concept_forward_func, x2y_model=x2y_model, x2c_model=x2c_model)

def calculate_concept_gradient(input_ids, attention_mask, target_index, concept_index, mode):
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)  

    with torch.no_grad():
        embeddings = x2y_model.model.get_input_embeddings()(input_ids)
        
    embeddings.requires_grad_(True)
    attention_mask = attention_mask.float()
    attention_mask.requires_grad_(True)
    attr = cg.attribute(
        (embeddings, attention_mask),
        mode=mode,
        target=target_index,
        target_concept=concept_index,
        n_concepts=5,
        target_layer_name='roberta.encoder.layer.11.output.dense',
        concept_layer_name='roberta.encoder.layer.11.output.dense',
    )

    return attr

# %%
df_test = pd.read_csv('dataset/test.csv')
# df_test = df_test.sample(1500, random_state=42)

# %%
df_test['concept_labels'] = df_test[['obscene', 'threat', 'sexual_explicit', 'insult', 'identity_attack']].values.tolist()
df_test.drop(columns=['obscene', 'threat', 'insult', 'severe_toxicity', 'id', 'identity_attack', 'sexual_explicit'], inplace=True, axis=1)
ds_test = Dataset.from_pandas(df_test)
df_test.head()
# Out:
#                                         comment_text  toxicity  \
# 0  Mr. Morneau has worked doubly hard to become o...         1
# 1  Well, naturally Flowers is against immigration...         1
# 2  Move to cash Larry then wait for the Trump slu...         0
# 3  “Our research indicates that even though [elec...         0
# 4  Trudeau is a dunderhead as the problem is as m...         1
#
#     concept_labels
# 0  [0, 0, 0, 1, 1]
# 1  [1, 0, 1, 1, 1]
# 2  [0, 0, 0, 0, 0]
# 3  [0, 0, 0, 0, 0]
# 4  [0, 0, 0, 1, 0]

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

def tokenize_function(examples):
    return tokenizer(examples["comment_text"], padding="max_length", truncation=True)

tokenized_dataset = ds_test.map(tokenize_function, batched=True)
tokenized_dataset.set_format("torch", columns=["input_ids", "attention_mask", "concept_labels", "toxicity"])

x2y_dl_test = DataLoader(tokenized_dataset, batch_size=8, shuffle=False)
# Out:
# /home/2017025/sgarg01/.python3-3.12-torch220/site-packages/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
results = []
x2y_dl_test = DataLoader(tokenized_dataset, batch_size=8, shuffle=False)
for batch in tqdm(x2y_dl_test, leave=True):
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    labels = batch['toxicity'].to(device)
    concept_labels = batch['concept_labels']

    target_logits = x2y_model(input_ids=input_ids, attention_mask=attention_mask)
    target_preds = torch.argmax(target_logits, dim=-1)

    incorrect_indices = (target_preds != labels).nonzero(as_tuple=True)[0]

    if len(incorrect_indices) > 0:
        for idx in incorrect_indices:
            sample_input_ids = input_ids[idx].unsqueeze(0)
            sample_attention_mask = attention_mask[idx].unsqueeze(0)
            sample_label = labels[idx].item()
            sample_concept_label = concept_labels[idx].unsqueeze(0)
            sample_sentence = tokenizer.decode(sample_input_ids.squeeze(), skip_special_tokens=True)

            concept_gradient = calculate_concept_gradient(sample_input_ids, sample_attention_mask, target_index=sample_label, concept_index=None, mode='chain_rule_independent')
            concept_gradient = concept_gradient[0].detach().cpu().numpy()

            concept_logits = x2c_model(input_ids=sample_input_ids, attention_mask=sample_attention_mask)
            concept_logits = torch.sigmoid(concept_logits).detach().cpu().numpy()

            target_logits_final = x2y_model(input_ids=sample_input_ids, attention_mask=sample_attention_mask)
            target_logits_final = torch.softmax(target_logits_final, dim=-1).detach().cpu().numpy()

            results.append({
                "sentence": sample_sentence,
                "target_logits": target_logits_final,
                "concept_logits": concept_logits,
                "concept_gradient": concept_gradient,
                "label": sample_label,
                "concept_label": sample_concept_label.cpu().numpy()  
            })
            
df_results = pd.DataFrame(results)
df_results.to_csv("analysis_sheets/final_misclassified_samples_with_concept_gradients.csv", index=False)

print("Process complete. Results saved to 'misclassified_samples_with_concept_gradients.csv'")
# Out:
#   0%|          | 0/1250 [00:00<?, ?it/s]
# Process complete. Results saved to 'misclassified_samples_with_concept_gradients.csv'

# %%
results
# Out:
# [{'sentence': "It's an idiotic system offering only one moronic choice. It lacks the integrity to offer a True/False choice, and is essentially meaningless. A lie politely expressed is bogus civility.",
#   'target_logits': array([[0.00230334, 0.9976967 ]], dtype=float32),
#   'concept_logits': array([[0.9518684 , 0.19160376, 0.50948566, 0.9963252 , 0.17970565]],
#         dtype=float32),
#   'concept_gradient': array([[0.0516965 , 0.04724283, 0.05041987, 0.08354744, 0.07352459]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': "I WAS RAPED BY AMY DEMBOSKI\n\nLet's talk about it, either validate or disprove it",
#   'target_logits': array([[0.04194589, 0.9580541 ]], dtype=float32),
#   'concept_logits': array([[0.32105634, 0.49041313, 0.22665249, 0.3756622 , 0.5685829 ]],
#         dtype=float32),
#   'concept_gradient': array([[0.03498284, 0.03125231, 0.0372651 , 0.04892586, 0.045274  ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 1, 1, 1, 1]])},
#  {'sentence': "I guess it's hard to keep an old race-baiting hypocrite like tangreedo down...\nHowever, if he doesn't understand the basic elements of the First Amendment, then he's not fit to hold any office. Let him waste more money running - as long as he's never voted in again.",
#   'target_logits': array([[0.0164366, 0.9835634]], dtype=float32),
#   'concept_logits': array([[0.18576749, 0.02642099, 0.1691049 , 0.90828776, 0.04892153]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.00292039, -0.06131317, -0.01748124,  0.1203261 , -0.06480377]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'I find it hard to take this congresswoman clown serious, she looks like a transgendered cowboy/girl. What a joker!',
#   'target_logits': array([[0.00215883, 0.9978411 ]], dtype=float32),
#   'concept_logits': array([[0.9405062 , 0.51551867, 0.91181475, 0.99713886, 0.22804555]],
#         dtype=float32),
#   'concept_gradient': array([[0.04099979, 0.02527652, 0.0420344 , 0.13830137, 0.04916368]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 1, 1, 1]])},
#  {'sentence': 'Sounds like a loser.  Or at least, an angry loser, lol',
#   'target_logits': array([[0.00198572, 0.9980142 ]], dtype=float32),
#   'concept_logits': array([[0.94199777, 0.23899746, 0.58028966, 0.9971602 , 0.21477231]],
#         dtype=float32),
#   'concept_gradient': array([[0.04056409, 0.0407019 , 0.04745767, 0.13001141, 0.06663446]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 0, 1, 0]])},
#  {'sentence': "As a cyclist in central Denver, I NEVER use bike lanes, and I'm not alone. I use less-traveled roads and don't ride at rush hour. It's too dangerous to do otherwise.\n\nI have a nice bike. I wonder how they will tax it. I'll buy my next one online if they play that stupid game.\n\nThanks to TABOR this stupid tax would have to be voted on",
#   'target_logits': array([[0.00217067, 0.9978294 ]], dtype=float32),
#   'concept_logits': array([[0.9471243 , 0.11408152, 0.2764158 , 0.99097973, 0.14360908]],
#         dtype=float32),
#   'concept_gradient': array([[0.04712687, 0.04933405, 0.052622  , 0.06711547, 0.07057706]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': "No, DeltaDag, that is an extremely unlikely possibility. Kim Jong Un is a tyrannical dictator who only remains in power with the force of his military. If there were truly sentiment in his favor among his civilian countrymen and women, we would hear other voices besides his own — bolstering his power. Instead, he must bow down to retired American basketball players like Dennis Rodman — in order to appease the growing youth movement against him within North Korea's own borders.",
#   'target_logits': array([[0.9056173, 0.0943827]], dtype=float32),
#   'concept_logits': array([[0.02822388, 0.0141201 , 0.16616306, 0.4923264 , 0.03444756]],
#         dtype=float32),
#   'concept_gradient': array([[-0.13449857, -0.11590698, -0.0760755 , -0.0783207 , -0.07729759]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Nefoundlanders will be paying $1.40/Liter  for gas Jan.  1st  with this new carbon tax despite oil at $50/barrel.  \n\nEnjoy your Liberals fools.',
#   'target_logits': array([[0.00267955, 0.9973205 ]], dtype=float32),
#   'concept_logits': array([[0.9597664 , 0.27413422, 0.84481287, 0.9951348 , 0.2502869 ]],
#         dtype=float32),
#   'concept_gradient': array([[0.05458354, 0.044597  , 0.05317389, 0.06606708, 0.06479008]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'Ohhh hahahahahahahaha! Another loony fairy tale from the big, fat, orange buffoon.',
#   'target_logits': array([[0.00508001, 0.99491996]], dtype=float32),
#   'concept_logits': array([[0.8191884 , 0.33463144, 0.7511801 , 0.99112153, 0.18326217]],
#         dtype=float32),
#   'concept_gradient': array([[0.04895541, 0.02279658, 0.05254846, 0.19073173, 0.03314659]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 1, 1, 1]])},
#  {'sentence': 'Wait, you think those guys have money?\nPart of their narrative is they can not find jobs because of all the illegals and blacks.',
#   'target_logits': array([[0.00914241, 0.99085754]], dtype=float32),
#   'concept_logits': array([[0.16531712, 0.05684416, 0.9626342 , 0.89525986, 0.09424005]],
#         dtype=float32),
#   'concept_gradient': array([[0.03130403, 0.02765793, 0.07629556, 0.0615321 , 0.03566671]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 1]])},
#  {'sentence': 'I would also add that there was Rome singular, its\' vassal provinces on the peninsula, and its\' conquered states, that resulted in unimaginable wealth obtained from plunder and genocidal practice to ensure obedience.  No judgement here as this was a practice of dominant peoples of the time since the dawn of civilization.  The Romans elevated it to a level of professionalism, arguably not repeated until the rule of Genghis Khan.  Rome\'s wealth bought allies that kept the empire intact and the inevitable response of the allies wanting a bigger piece of the pie.  That being said, wealth generates wealth and the western civilized world maintained a precarious alliance, with Rome being majordomo.  The precariousness was exacerbated by Rome comprising of dominant familial tribes and ongoing civil war from the Republic to the age of emperors, an age of obscene hedonism which may have been caused by lead consumption.  "We are all winners" being a latter day milder form of macro indulgence.',
#   'target_logits': array([[0.9944931 , 0.00550695]], dtype=float32),
#   'concept_logits': array([[0.03213527, 0.03360596, 0.10319497, 0.19014658, 0.05121467]],
#         dtype=float32),
#   'concept_gradient': array([[-0.14295763, -0.08502132, -0.09473597, -0.11028718, -0.07013594]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'If Trump announced the sky was blue there would be 300 comments here on why he was an idiot.  Saving what is left of manufacturing is not a bad thing people.  Canada and the US do not compete with Mexico on labor with the current system.  Most new infrastructure and investment is going to our far south neighbors with a pittance left for Canada and the US to keep the sheep happy.',
#   'target_logits': array([[0.00225904, 0.997741  ]], dtype=float32),
#   'concept_logits': array([[0.94573456, 0.13792698, 0.67428446, 0.99558395, 0.2096609 ]],
#         dtype=float32),
#   'concept_gradient': array([[0.04107953, 0.05351333, 0.04632382, 0.04546883, 0.07329272]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'The point is we have had dozens of ice ages over millions of years.... and then it warmed up each time over the millennia.  The questions is, who had "SUV\'s" that warmed up the planet each time in the last 100,000,000 years?  This is natural, not man-made!  BOTTOM LINE:  don\'t believe anybody that says "it is YOUR fault, so you owe "us" more taxes, so we can "fix it"!',
#   'target_logits': array([[0.99705386, 0.00294613]], dtype=float32),
#   'concept_logits': array([[0.01736528, 0.01190942, 0.0261954 , 0.09595633, 0.02033664]],
#         dtype=float32),
#   'concept_gradient': array([[-0.23818225, -0.1802393 , -0.20171846, -0.17011371, -0.17265582]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "'\nTrump looking 'presidential'.\n.\nhttps://pbs.twimg.com/media/CzqZLG8XAAEkeeg.jpg:small\n.",
#   'target_logits': array([[0.99394894, 0.0060511 ]], dtype=float32),
#   'concept_logits': array([[0.01742658, 0.00927508, 0.01928732, 0.1618617 , 0.01344829]],
#         dtype=float32),
#   'concept_gradient': array([[-0.03056751,  0.00573756, -0.01107561, -0.05464167,  0.06852942]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "ha ha. guests, i'm in jackson, wy today and posted while cleaning out cabin. hope you're having great day.",
#   'target_logits': array([[0.9946026, 0.0053974]], dtype=float32),
#   'concept_logits': array([[0.01580603, 0.00952148, 0.0275993 , 0.06758666, 0.02714938]],
#         dtype=float32),
#   'concept_gradient': array([[-0.19890714, -0.15625742, -0.15900798, -0.15252131, -0.11346253]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "lowtone 123 I don't know about Marcus Shaver jr. but another that is still looking at Hawaii is a 6-3 170lb shooting guard Jahvon Blair also interested in him is De Paul, Georgia Tech, Kent State and St. Bonaventure he is regarded as a 3 star player same as 6'5 Avea  from Kahuku who already signed with Hawaii.",
#   'target_logits': array([[0.99642086, 0.0035791 ]], dtype=float32),
#   'concept_logits': array([[0.01241   , 0.00788652, 0.02510072, 0.03179151, 0.03328962]],
#         dtype=float32),
#   'concept_gradient': array([[-0.08324149, -0.02627631, -0.05106977, -0.10112998, -0.00356564]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'A couple of Trump admirer friends of mine were telling me of Trump\'s great sacrifice of not taking his presidential salary.  That\'s $400th for the most powerful and important job on the planet, which to me seems a bit low.  It reminds me of police in the third world who survive on "tips".\n\nAnyway, $400th is next to nothing to a billionaire president.  It\'s even closer to nothing if the president doesn\'t reveal his holdings and meets regularly with the people who manage his investments.  Closer to nothing, still, if he inexplicably threatens or supports publicly traded companies on a regular basis.',
#   'target_logits': array([[0.9955173, 0.0044827]], dtype=float32),
#   'concept_logits': array([[0.02390638, 0.01526234, 0.03692691, 0.2788787 , 0.020072  ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.22359931, -0.19252893, -0.19951615, -0.10268433, -0.21359013]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "Alaska Airlines is a private company.  They have the right to deal with unruly passengers as they see fit.  Here they sided with their employee and threw the jerk off.  Good for the pilot, the flight crew and the company.  Those who find the airline's decision unwarranted can demonstrate their disapproval by taking another airline, driving or walking.  As a not infrequent flier I've had to sit on planes listening to loud mouth jerks for several hours more than once.  It makes the experience unpleasant for everyone else.  So in my mind they didn't violate the rights of one passenger, they upheld the rights of all the others to reach their destination in a peaceful environment, aided by a crew that wasn't distracted by a troublemaker.  That's a company caring about its good customers.",
#   'target_logits': array([[0.0178393, 0.9821607]], dtype=float32),
#   'concept_logits': array([[0.7045761 , 0.14847453, 0.13395245, 0.8567657 , 0.05162533]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.04430171,  0.00595824, -0.00131638,  0.08064105, -0.01753   ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 1, 1, 0]])},
#  {'sentence': 'It was a culture of drunken violence and neglect the white man was trying to save the kids from. Still do.',
#   'target_logits': array([[0.02488049, 0.97511953]], dtype=float32),
#   'concept_logits': array([[0.09504189, 0.07560734, 0.9150105 , 0.8410816 , 0.16740522]],
#         dtype=float32),
#   'concept_gradient': array([[-0.01109278, -0.01771284,  0.15282193,  0.11574481, -0.00040639]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 1]])},
#  {'sentence': "Actually, they were the smart women who did not believe the matriarchy who call everything rape and everything misogyny.  \n\nOh, by the way, it has been two minutes and I haven't been raped.",
#   'target_logits': array([[0.01871497, 0.981285  ]], dtype=float32),
#   'concept_logits': array([[0.28283647, 0.9165636 , 0.7237641 , 0.7584034 , 0.41961145]],
#         dtype=float32),
#   'concept_gradient': array([[0.03160393, 0.12318234, 0.10131449, 0.12264758, 0.06071583]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 1, 1, 1, 1]])},
#  {'sentence': "See this is what I meant.  You are just as closed minded as those you accuse of being closed minded.  Typical left hypocrisy.  I don't need to accuse you.  Just wind you up and let you go and you end up proving my point for me.  Its cool though.  Its just comments, right?",
#   'target_logits': array([[0.07363568, 0.92636436]], dtype=float32),
#   'concept_logits': array([[0.12162925, 0.03095673, 0.24735472, 0.89087945, 0.29458502]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.01763085, -0.01096443,  0.0172094 ,  0.09030891,  0.03215606]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': "Far too late. Watching most of the team intentionally insult so many Americans last week was more than enough. After more than 35 years, I'm done with the NFL and idiot millionaires telling me my country sucks.",
#   'target_logits': array([[0.00182008, 0.9981799 ]], dtype=float32),
#   'concept_logits': array([[0.99228024, 0.5540951 , 0.924225  , 0.99744785, 0.39598313]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.02951187,  0.03882449,  0.03921447, -0.0723266 ,  0.06840862]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 1, 1, 1]])},
#  {'sentence': "I am torn. I understand Mr. Bennett's position. Trump is a an accused rapist, he takes advantage of old people, degrades women, makes fun of people with disabilities and the list goes on of despicable acts. But I also understand the owners views. I don't think there is anyone, other than Hitler, Stalin that can go lower than Trump, so respect the office of the President, no matter what kind of pig occupies it.",
#   'target_logits': array([[0.00342053, 0.99657947]], dtype=float32),
#   'concept_logits': array([[0.88603365, 0.8527079 , 0.88204426, 0.99299365, 0.34407562]],
#         dtype=float32),
#   'concept_gradient': array([[0.04427135, 0.03932469, 0.05385164, 0.09756618, 0.04662593]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 1, 1, 1]])},
#  {'sentence': 'Always pleasure GREENLEAF, just google "Plate Climatology Theory", it has only come to the fore-front of research in the last decade or so, there are many articles on it. It\'s in it\'s infancy, but as it points out, data on this underwater activity with vents and huge volcanoes that truly dwarf those on land, especially the plate faults and their ever releasing not just CO2, but methane and other gases that effect the environment, has been scarce. As you point out, many through history believed their impact to be negligible, but that opinion is being researched, new data gathered and challenged. \n\n\nOur government is very much part of the polarized political debate on climate change, sadly, when opposition presents, it is dismissed often out of hand. We assumed the underwater volcanoes and vents acted a particular way as to be of no concern, they don\'t throw into the atmosphere thus they don\'t bring cooling. \n\n\nThis damn "CIVIL" format limits me from explaining, it\'s awful! I\'d say more',
#   'target_logits': array([[0.01792889, 0.9820711 ]], dtype=float32),
#   'concept_logits': array([[0.9248013 , 0.03986334, 0.11498509, 0.85935813, 0.04757253]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.08260703, -0.01171273, -0.00164453,  0.08860166, -0.01916547]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': "Well that's not dumber than your usual comments. Equally uninformed and insensitive   perhaps. You just want people to Die. No, that's a lib line,",
#   'target_logits': array([[0.01646735, 0.98353267]], dtype=float32),
#   'concept_logits': array([[0.61441624, 0.12197515, 0.31053326, 0.9584336 , 0.7528998 ]],
#         dtype=float32),
#   'concept_gradient': array([[0.04074597, 0.00431284, 0.02135516, 0.11419968, 0.06230216]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 0, 1, 1]])},
#  {'sentence': "You're a miserable little thing, aren't you? Let me guess: white male. Beardy. Prrrrrobably MRA.\n\nHow close am I?",
#   'target_logits': array([[0.00416459, 0.9958354 ]], dtype=float32),
#   'concept_logits': array([[0.7938046 , 0.29619503, 0.9812056 , 0.9891862 , 0.19306746]],
#         dtype=float32),
#   'concept_gradient': array([[0.04702475, 0.02959273, 0.11916225, 0.13805203, 0.04396227]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'And, all Spacey needs to do is tweet that the guy is lying, and all the trumpeteers will believe him.',
#   'target_logits': array([[0.36368096, 0.63631904]], dtype=float32),
#   'concept_logits': array([[0.0529105 , 0.01531254, 0.06454626, 0.66060454, 0.06511908]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.0264612 , -0.00153642,  0.01142582,  0.09329288,  0.01170319]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 1, 0, 1, 0]])},
#  {'sentence': 'If people disagree, they are welcome to state why.  Voting the comment off the board because they do not like it is not the purpose of this system, we are only supposed to vote things down if they are offensive.  Furthermore, voting it down is just dodging the argument rather than engaging it.',
#   'target_logits': array([[0.9966523 , 0.00334776]], dtype=float32),
#   'concept_logits': array([[0.02059822, 0.01894972, 0.01995229, 0.09279018, 0.06325534]],
#         dtype=float32),
#   'concept_gradient': array([[-0.20593514, -0.12877105, -0.21520822, -0.17198402, -0.06810693]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Moyane to jail,the better way to resolve this. Parliament is a lame duck.',
#   'target_logits': array([[0.02232357, 0.9776764 ]], dtype=float32),
#   'concept_logits': array([[0.20815256, 0.06135889, 0.15271045, 0.9049343 , 0.6046498 ]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.01973008, -0.01292313, -0.00221346,  0.12091795,  0.06680641]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 1, 1, 1]])},
#  {'sentence': 'United we stand, divided we fall!!  Everyone in America except the American Indians are immigrants of other countries and we became powerful by working together.  Where would we be if we fought each other in the past?  Our enemies are hoping that we fight each other so they can conquer us, and they will.  What happened to the Nazis of the past will happen to us if we start getting rid of each other.  The only way we can survive as Americans is to accept that everyone is equal and to respect each other because all lives matter.  Let us all do on to others as you would have them do on to you.  God Bless America!!!!',
#   'target_logits': array([[0.973129  , 0.02687101]], dtype=float32),
#   'concept_logits': array([[0.03221054, 0.01682247, 0.4932985 , 0.2390096 , 0.30955252]],
#         dtype=float32),
#   'concept_gradient': array([[-0.22326438, -0.19052768, -0.06893989, -0.16999598, -0.0448339 ]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "Lol how could you not reference Trump or farage  who campaigned brexit or any new EU leader that will stand up against the guise that immigration is our saviour and must be done for humanity. By seeing how you cannot make that connection shows me who the idiot is. Secondly in regards to money that is laundered out of Canada, hate to say it but its laundered everywhere and it is certainly not the citizens of those countries on the receiving end.  It's politicians. The same politicians who steal the money from us Canadians that contribute to ridiculously high taxes and  ridiculously stupid regulations. Americans were sick of the typical politician in the USA who steals from them in the same forms of taxes and regulations, which is then laundered\nOut of the country to everywhere. Trump noticed as have the citizens. We Canadians by our recent vote have not, but we did not have a politician to say these things. Once again by you not recognizing these connections I can see who the idiot is.",
#   'target_logits': array([[0.00214817, 0.99785185]], dtype=float32),
#   'concept_logits': array([[0.9682787 , 0.23690048, 0.8266045 , 0.99540764, 0.22578101]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.02303572,  0.06163173,  0.03493952, -0.04315544,  0.0911888 ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': "Clinton lied under oath which is why he was impeached.   The sex\nwas what he lied about.  Their both congenital liars.  Obama is a \npathological liar.   He should be tried for Treason.  Oregon isn't any better.",
#   'target_logits': array([[0.00441266, 0.99558735]], dtype=float32),
#   'concept_logits': array([[0.8929387 , 0.9680962 , 0.8175468 , 0.9931379 , 0.70352095]],
#         dtype=float32),
#   'concept_gradient': array([[0.05300332, 0.05884152, 0.05983087, 0.12517948, 0.0545953 ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 1, 1, 1]])},
#  {'sentence': 'Okay why are we still talking about this useless attention seeking piece of crap woman?',
#   'target_logits': array([[0.00170803, 0.998292  ]], dtype=float32),
#   'concept_logits': array([[0.99610066, 0.68256205, 0.6587403 , 0.9960936 , 0.26160854]],
#         dtype=float32),
#   'concept_gradient': array([[0.07833736, 0.0374844 , 0.05475451, 0.06260541, 0.07362795]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': "We've all been had.",
#   'target_logits': array([[0.9825706, 0.0174294]], dtype=float32),
#   'concept_logits': array([[0.02291634, 0.02886506, 0.01236664, 0.0509358 , 0.03043171]],
#         dtype=float32),
#   'concept_gradient': array([[-0.1573741 , -0.08233251, -0.22315063, -0.17560835, -0.0867504 ]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "Excellent commentary. I support your cause and case even though I don't live in the area. How can this process have even gotten this far without a viewable plan?",
#   'target_logits': array([[0.9986021 , 0.00139793]], dtype=float32),
#   'concept_logits': array([[0.01220841, 0.00872445, 0.01328756, 0.03566992, 0.0154043 ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.15614834, -0.08658932, -0.14504245, -0.14904709, -0.07954723]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'The dumb LW2 failed to mention a very crucial piece of data: the age of her son. Was he 4? 12? Age makes a big difference. A four year old (or close to that age) calls things as they see it. Older children will say "You\'re fat!" to be mean. If this boy is very young, he may have just been innocently exclaiming an observation, as he would if he saw a big dog: "Your dog is big!"',
#   'target_logits': array([[0.00261699, 0.99738294]], dtype=float32),
#   'concept_logits': array([[0.73552155, 0.09659463, 0.24349844, 0.9880838 , 0.08406855]],
#         dtype=float32),
#   'concept_gradient': array([[0.04303741, 0.04444119, 0.04662752, 0.07600442, 0.06584504]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'I always laugh when I hear that comeback, you must believe a president is handed a checkbook when they are elected to office, then sits back at their desk and writes checks.',
#   'target_logits': array([[0.9944534 , 0.00554658]], dtype=float32),
#   'concept_logits': array([[0.02580389, 0.01226379, 0.02871034, 0.26621243, 0.0324723 ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.18256603, -0.17288236, -0.1922516 , -0.10099943, -0.1278304 ]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Really, really well said: Thank You!',
#   'target_logits': array([[0.9962346, 0.0037654]], dtype=float32),
#   'concept_logits': array([[0.01035744, 0.00737467, 0.0125111 , 0.02313828, 0.01147103]],
#         dtype=float32),
#   'concept_gradient': array([[-0.1318361 , -0.03294618, -0.09462216, -0.14598851, -0.01183112]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Protest with your wallet, do not go to the U.S.A. for day trips or holidays. Go to Newfoundland instead of Disneyland. Buy a Canadian made vehicle. Think of creative ways not to buy American. Trump loves that every one is mad. He cares less, the real problem is what is he doing now that every one is focussed on this.',
#   'target_logits': array([[0.94880885, 0.05119116]], dtype=float32),
#   'concept_logits': array([[0.04780804, 0.01440705, 0.17727992, 0.5705962 , 0.04546864]],
#         dtype=float32),
#   'concept_gradient': array([[-0.14864403, -0.17762041, -0.09307677, -0.07333054, -0.12009252]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Do you even read things before you comment? They have not been charged with murder As of yet. So she might have died naturally and they covered that up because they have a charge of concealing a corpse. What a joke pf a screenname, Boss. You the biggest idiot boss in the wprld then',
#   'target_logits': array([[0.00170169, 0.99829835]], dtype=float32),
#   'concept_logits': array([[0.99220407, 0.3401967 , 0.60350496, 0.9970394 , 0.8019842 ]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.03462507,  0.04220792,  0.05242665, -0.01710801,  0.04399686]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': 'Clearly, you are a cut below bologna. Chicken lips, pork butt with a little meat glue.',
#   'target_logits': array([[0.00438654, 0.99561346]], dtype=float32),
#   'concept_logits': array([[0.95101184, 0.9596752 , 0.8474347 , 0.9852438 , 0.45602047]],
#         dtype=float32),
#   'concept_gradient': array([[0.0565497 , 0.04844699, 0.05105631, 0.10880031, 0.03856048]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 1, 1, 0]])},
#  {'sentence': 'James clearly does not.',
#   'target_logits': array([[0.9931166 , 0.00688331]], dtype=float32),
#   'concept_logits': array([[0.00740131, 0.00834016, 0.03213966, 0.06468422, 0.01115117]],
#         dtype=float32),
#   'concept_gradient': array([[-0.26086277, -0.13127084, -0.12164859, -0.15686104, -0.12410879]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'I don\'t see how any type of "political considerations" or any fear of schism, or any desire of any type of synodal process, or any other tings for that matter, could trump a concern for the safety and well-being of children on the part of moral person, but, most especially on the part of a leader of the Catholic Church.  To me, the motives are irrelevant.  It is all so terribly, terribly wrong.',
#   'target_logits': array([[0.98277414, 0.01722585]], dtype=float32),
#   'concept_logits': array([[0.03326222, 0.02614612, 0.5103949 , 0.3088441 , 0.0362748 ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.18745016, -0.1336058 , -0.05289312, -0.11663651, -0.12646873]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Good anecdotal response, argyle5663 \nGood luck with getting experts into elementary schools. One barrier is that with advanced qualifications they will cost more; secondly, staffing a school is subject to limitations ( student/teacher ratio ) and such calculations work against numerous specialist teachers. Look at music and physical education programs for examples. Specialists in elementary schools are almost non-existent.',
#   'target_logits': array([[0.9984023 , 0.00159769]], dtype=float32),
#   'concept_logits': array([[0.01235997, 0.00927355, 0.01883298, 0.04720202, 0.01560038]],
#         dtype=float32),
#   'concept_gradient': array([[-0.1608381 , -0.08981489, -0.12996852, -0.127155  , -0.0759457 ]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'RandR, the season at the moment is hating non-white immigrants.',
#   'target_logits': array([[0.01932236, 0.98067766]], dtype=float32),
#   'concept_logits': array([[0.15934666, 0.05514134, 0.9609228 , 0.8556297 , 0.1750914 ]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.00803859, -0.02110956,  0.17560072,  0.11728586,  0.00155243]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'Probably, like you, an idiot.',
#   'target_logits': array([[0.00170975, 0.99829024]], dtype=float32),
#   'concept_logits': array([[0.9930119 , 0.21386689, 0.4439914 , 0.99641305, 0.20095944]],
#         dtype=float32),
#   'concept_gradient': array([[0.0642212 , 0.07077646, 0.07410111, 0.04151628, 0.11246254]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': 'I have yet to see a woman on a roof stripping shingles. Even carrying and nailing shingles. I have never seen a woman troweling concrete or working on a concrete crew. This equal rights foolishness has gone overboard.',
#   'target_logits': array([[0.01986112, 0.9801389 ]], dtype=float32),
#   'concept_logits': array([[0.24639589, 0.03667519, 0.5365454 , 0.91647136, 0.07402957]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.02862352, -0.00524833,  0.04195378,  0.09727327, -0.00037343]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 1]])},
#  {'sentence': 'Wish her the very best of success.  She will notice almost immediately that being a head coach changes relationships with the players.  Assistants and Associates can joke around and be "best buds"; not so the HC.   The HC tells them who plays, what to do, when to do it, and how to do it.  This makes being friends a "a very trying" effort at best.',
#   'target_logits': array([[0.99815863, 0.00184134]], dtype=float32),
#   'concept_logits': array([[0.01055038, 0.01218142, 0.01303916, 0.0297475 , 0.01704999]],
#         dtype=float32),
#   'concept_gradient': array([[-0.12687935, -0.04488087, -0.10423097, -0.12266413, -0.02671156]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Trump and 50 million Americans appear to be more and more idiots every day. You just listen to those who voted for him-case in point the USA ambassador Nikki the other day. "He is our president so he can do anything he wants (responding to Comey firing)". It appears that to many Republican voters President and God are about one and the same. Scary.',
#   'target_logits': array([[0.00211154, 0.9978885 ]], dtype=float32),
#   'concept_logits': array([[0.95870924, 0.19663075, 0.9015368 , 0.997063  , 0.29217616]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.03305943,  0.05753521,  0.03772281, -0.02535032,  0.07775109]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': 'Because the Clinton garbage is FAKE NEWS, little snowflake!',
#   'target_logits': array([[0.0020207 , 0.99797934]], dtype=float32),
#   'concept_logits': array([[0.9752447 , 0.25503105, 0.75690496, 0.9974305 , 0.22769211]],
#         dtype=float32),
#   'concept_gradient': array([[0.04228693, 0.0481693 , 0.04315275, 0.03144103, 0.07743331]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 0]])},
#  {'sentence': 'You are dumb I meant to make it clear to someone like you, I\'m against saying one thing and doing another. Hillary"trump is a racist bigot and womanizer", Hillary "hey Jay Z how many hoes have you bitch slapped lately come do my concert" I\'m all for freedom of speech. And I\'ll stand by your side with my gun to defend our freedoms. I have nothing against 1St amendment freedom of speech or peaceful protest. I have something against those who preach one thing and perform another way and support the behavior they shun. Look back in time Hillary is a sell out to power and politics. But not her first few years, she didn\'t fit the mold and if she didn\'t conform their political careers were over she stepped in line as politicians wife. Watch the documentary. She\'s a sell out and all dems got F**ked when Bernie got jipped off the ticket, that\'s when you lost the election bud.',
#   'target_logits': array([[0.00196556, 0.9980344 ]], dtype=float32),
#   'concept_logits': array([[0.9897456 , 0.78293324, 0.8931975 , 0.996849  , 0.604621  ]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.00539279,  0.03055646,  0.03170941, -0.10732326,  0.04929856]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 1, 1, 1]])},
#  {'sentence': "Oh, believe me, there were many times I tried to engage in the act but was turned down by respectable women.  I understand it's a lot easier for men these days, though.",
#   'target_logits': array([[0.987432  , 0.01256804]], dtype=float32),
#   'concept_logits': array([[0.02566152, 0.05255092, 0.4509118 , 0.16267015, 0.0188684 ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.2347408 , -0.11543378, -0.05811163, -0.17812316, -0.21680439]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Good to the CEOs who stood up against Drump and his altra right supremists. When will the GOP stand up as well?? Hypocrites.',
#   'target_logits': array([[0.00325807, 0.99674195]], dtype=float32),
#   'concept_logits': array([[0.7953195 , 0.10329281, 0.77438295, 0.9921543 , 0.15714581]],
#         dtype=float32),
#   'concept_gradient': array([[0.04751411, 0.05887081, 0.04957633, 0.05821624, 0.07834922]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': "No I didn't - what year did you move here, ignorant?\n\ndo you support sociopaths, or did you make a new account to be him? Stop being a sick person.",
#   'target_logits': array([[0.00188028, 0.99811965]], dtype=float32),
#   'concept_logits': array([[0.983032  , 0.25493613, 0.7259361 , 0.9977805 , 0.24129014]],
#         dtype=float32),
#   'concept_gradient': array([[0.04810474, 0.05837622, 0.05304163, 0.02732275, 0.08566158]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': 'Your kidding, right?  This submission process would be like --posting a 3x5 index card to a supermarket notice board.  Nobody cares, really, -- least of all the editors.',
#   'target_logits': array([[0.99475056, 0.0052495 ]], dtype=float32),
#   'concept_logits': array([[0.02913913, 0.01063378, 0.02233225, 0.28238925, 0.02169522]],
#         dtype=float32),
#   'concept_gradient': array([[-0.19534464, -0.22221835, -0.24250364, -0.10135663, -0.20619133]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'His videos are lies.',
#   'target_logits': array([[0.35053337, 0.64946663]], dtype=float32),
#   'concept_logits': array([[0.0673536 , 0.01655039, 0.08380806, 0.86927277, 0.04078906]],
#         dtype=float32),
#   'concept_gradient': array([[0.04984106, 0.03348032, 0.04037029, 0.10981134, 0.03285871]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 0]])},
#  {'sentence': '"Racism is evil, and those who cause violence in its name are criminals and thugs, including the KKK, neo-Nazis and white supremacists and other hate groups that are repugnant to everything we hold dear as Americans," the president said from the White House.\n.\nSo Clay, you are a dumbass.',
#   'target_logits': array([[0.00172169, 0.99827826]], dtype=float32),
#   'concept_logits': array([[0.9903486 , 0.57439387, 0.9732965 , 0.9966851 , 0.6765078 ]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.0428809 ,  0.038182  ,  0.04885073, -0.00829297,  0.04836397]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 1, 1, 1]])},
#  {'sentence': 'Bad call. From everything that has been written, it seems that APD is being mute on the case and the ADN is gathering its info from the doctors and Fish and Game. My gut tells me that APD is on an active case that is sensitive and is keeping its collective mouth closed.',
#   'target_logits': array([[0.99468505, 0.00531496]], dtype=float32),
#   'concept_logits': array([[0.04368485, 0.02083078, 0.02303577, 0.23141803, 0.03118251]],
#         dtype=float32),
#   'concept_gradient': array([[-0.08032992, -0.06647307, -0.11524729, -0.07082463, -0.05271472]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'income sprinkling is a very minor part of this legislated theft.....at least educate yourself before you show your ignorant envy to the world.',
#   'target_logits': array([[0.00591349, 0.9940865 ]], dtype=float32),
#   'concept_logits': array([[0.67312306, 0.11952698, 0.3550737 , 0.9886834 , 0.15186584]],
#         dtype=float32),
#   'concept_gradient': array([[0.05077534, 0.01098185, 0.03372844, 0.19052033, 0.02522926]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 0]])},
#  {'sentence': "If the privatization effort leads to a system like Canada's I would be all for it. But also bear in mind that Canada has more control over this industry, has better benefits for employees including unions, and generally takes better care of business than Trump (six bankruptcies, umpteen law suits, settlement in Trump U for $25M, etc. etc.).\n\nSeeing the machinations of the Trump administration makes me wonder if it would be another excuse to pad the incomes of Trump's chosen few at the expense of quality and cost of service. Trump is known for welching on his obligations and leaving vendors and consumers at risk. I don't have any reason to assume otherwise until I see more details about the execution of this proposal.\n\nShorter: I don't trust Trump to do right by the American people. Prove me wrong.",
#   'target_logits': array([[0.997684  , 0.00231599]], dtype=float32),
#   'concept_logits': array([[0.01858568, 0.01153715, 0.05068069, 0.24158545, 0.02571741]],
#         dtype=float32),
#   'concept_gradient': array([[-0.18260948, -0.14648944, -0.11392687, -0.08846169, -0.10259195]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "I don't even believe you were stopped at a roadside check the other day.",
#   'target_logits': array([[0.9971252 , 0.00287475]], dtype=float32),
#   'concept_logits': array([[0.01503941, 0.01077832, 0.01446299, 0.1191543 , 0.01919455]],
#         dtype=float32),
#   'concept_gradient': array([[-0.16661485, -0.11147401, -0.1655269 , -0.10348161, -0.10106321]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Maybe they would have shot him. Sixty-five guns on the street, probably Islamic terrorists. Good job Drahgonman.',
#   'target_logits': array([[0.01957854, 0.9804215 ]], dtype=float32),
#   'concept_logits': array([[0.12582515, 0.04372939, 0.90966   , 0.7401542 , 0.92707956]],
#         dtype=float32),
#   'concept_gradient': array([[0.03617118, 0.02903253, 0.0683827 , 0.06400277, 0.08094175]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 1, 0, 0, 1]])},
#  {'sentence': 'I agree; the Conservatives are nothing but hypocrites and perhaps the NDP are as well.  We will have to wait and see if the private members bill the NDP ethics critic brings forward will ban these unseemly events outright.',
#   'target_logits': array([[0.00580256, 0.9941975 ]], dtype=float32),
#   'concept_logits': array([[0.3861753 , 0.06699325, 0.475488  , 0.97436315, 0.0731795 ]],
#         dtype=float32),
#   'concept_gradient': array([[0.04022605, 0.02885859, 0.04228846, 0.10191771, 0.038985  ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 1]])},
#  {'sentence': 'Does that mean Jews are cannibals?',
#   'target_logits': array([[0.00954706, 0.990453  ]], dtype=float32),
#   'concept_logits': array([[0.15220952, 0.05937533, 0.9243898 , 0.7883186 , 0.09679952]],
#         dtype=float32),
#   'concept_gradient': array([[0.02721027, 0.01779745, 0.10892007, 0.07492007, 0.01934761]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 1]])},
#  {'sentence': 'Sometimes a punch in the nose is effective as the Roo kicks the crap out of your dog. Knowing all along the Roo can kick the crap out of you.  Just that hesitation can stop further damage to get the adults back in the room.',
#   'target_logits': array([[0.00906193, 0.99093807]], dtype=float32),
#   'concept_logits': array([[0.9379114 , 0.41566408, 0.426269  , 0.9470094 , 0.89237815]],
#         dtype=float32),
#   'concept_gradient': array([[0.0862013 , 0.01774211, 0.03116722, 0.12944025, 0.09617358]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 0, 1, 1]])},
#  {'sentence': "This is all George W. Bush's fault.",
#   'target_logits': array([[0.94255704, 0.05744294]], dtype=float32),
#   'concept_logits': array([[0.01832383, 0.00911855, 0.0946849 , 0.34019372, 0.03295811]],
#         dtype=float32),
#   'concept_gradient': array([[-0.19043604, -0.16687177, -0.09978779, -0.10727767, -0.08017234]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Are we on a slippery slope? Will this lead to a full-scale involvement of our forces in the Syrian civil war? Congresswoman Gabbard is right to question this. Thousands of civilians are being murdered in Turkey, but we are not getting involved there at all.',
#   'target_logits': array([[0.9935448 , 0.00645523]], dtype=float32),
#   'concept_logits': array([[0.02038878, 0.01602566, 0.24503997, 0.17930444, 0.2720918 ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.18859392, -0.1166111 , -0.07491396, -0.13488281, -0.01963851]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Absolutely. We have some idiot drivers around here. Speeders and tailgaters in particular.',
#   'target_logits': array([[0.00167586, 0.9983241 ]], dtype=float32),
#   'concept_logits': array([[0.9955876 , 0.41474593, 0.74409676, 0.9965745 , 0.29482663]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.03583033,  0.04529638,  0.04824302, -0.01530533,  0.0804202 ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 0, 1, 0]])},
#  {'sentence': 'That money would buy about 200 MRI machines. Would have helped a lot of Canadians to have faster access to a diagnosis. But no - not important for Mr. Sunny Ways.',
#   'target_logits': array([[0.9981573 , 0.00184267]], dtype=float32),
#   'concept_logits': array([[0.01053735, 0.0088646 , 0.03898934, 0.07255155, 0.01327953]],
#         dtype=float32),
#   'concept_gradient': array([[-0.15924263, -0.08593877, -0.08060244, -0.10023698, -0.07263486]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "I would certainly like that life of captivity with lots of food and protection from predators over the life of a cow in a factory farm stall who never sees daylight and gets a pneumatic bolt blown through its skull so it can be meat for your children's lunchables.",
#   'target_logits': array([[0.70234996, 0.29765004]], dtype=float32),
#   'concept_logits': array([[0.03305501, 0.01785088, 0.05606247, 0.2220087 , 0.4602008 ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.09347559, -0.05912728, -0.08505652, -0.09228718, -0.02943086]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "What pathetic boo-hoo tripe from the election-deniers. Never have I seen such childish behavior from adults. It's obvious they have learned nothing. The sore-loser crowd is throwing a hissy fit tantrum that will somehow translate into victory in '18?  That is a laughable assertion. Liberals think television shows like West Wing and SNL represent reality.  They live in a bubble of fear and hysterical hyperbole.",
#   'target_logits': array([[0.00444021, 0.9955598 ]], dtype=float32),
#   'concept_logits': array([[0.7106176 , 0.1656696 , 0.70413035, 0.9906227 , 0.16810794]],
#         dtype=float32),
#   'concept_gradient': array([[0.05028028, 0.02214262, 0.05767285, 0.17374426, 0.03700906]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 1]])},
#  {'sentence': "I'm pretty excited about having the candidates perform feats of strength like this. Maybe Jules can ride a unicycle down Mt. Tabor.",
#   'target_logits': array([[0.9959942, 0.0040058]], dtype=float32),
#   'concept_logits': array([[0.01231447, 0.01256   , 0.02502157, 0.07010328, 0.01969961]],
#         dtype=float32),
#   'concept_gradient': array([[-0.18499511, -0.10043763, -0.14041108, -0.1336685 , -0.09534644]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'I have, and worse. In fact, at a company event, a runt of a man, a top performer of my company, full of liquid courage, looked me right in the eye and slurred, "we don\'t like n*ggers." One of his colleagues looked at him in horror and demanded he apologize to me, and he slurred that he was "just kidding," but of course, he wasn\'t. That was back in the day. I have many more stories. If I knew then as a very young woman what I know now, I would have filed many, many, many complaints.',
#   'target_logits': array([[0.0330359, 0.9669641]], dtype=float32),
#   'concept_logits': array([[0.8795894 , 0.7045508 , 0.2554743 , 0.73513305, 0.0779907 ]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.07892569,  0.04718893,  0.01131335,  0.0786351 , -0.01809425]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'Actually, what I found a little later is that the precise number had become a point of American rhetorical harrumphing. Alt.right sites were suggesting that the turn out was actually a very low in relationship to what had been predicted by organizers. See http://dailycaller.com/2017/02/20/anti-trump-science-rally-expected-10000-attendees-got-a-few-hundred/. Like I said, I don\'t know what the right figure is, but suspect that it might have been lower than a few thousand. The problem is that if it was three hundred and 3,000 would be a "few" thousand, then we are talking about something approaching an order of magnitude over-estimate. That\'s something that would have been a big no-no in a scientific paper.',
#   'target_logits': array([[0.9977786 , 0.00222135]], dtype=float32),
#   'concept_logits': array([[0.01347882, 0.00845187, 0.02904544, 0.10921013, 0.0150181 ]],
#         dtype=float32),
# ...
#   'target_logits': array([[0.00242873, 0.9975713 ]], dtype=float32),
#   'concept_logits': array([[0.9328222 , 0.7313373 , 0.9170305 , 0.99477226, 0.21996395]],
#         dtype=float32),
#   'concept_gradient': array([[0.04548848, 0.03274006, 0.05247569, 0.06458348, 0.06079972]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 1, 1, 0]])},
#  {'sentence': 'Trump is a materialist, a bully, and a liar.  Jesus taught us to not worry about riches, not cast the first stone, and that the truth shall set you free.',
#   'target_logits': array([[0.00425948, 0.99574053]], dtype=float32),
#   'concept_logits': array([[0.825492  , 0.25795418, 0.841603  , 0.99520004, 0.48493066]],
#         dtype=float32),
#   'concept_gradient': array([[0.05151714, 0.0294978 , 0.05638008, 0.16077776, 0.04878253]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'Why are so many Alaskans so ignorant! \n\nThe comments are what I\'m referring to; why is it so hard to believe that someone might not know "who" shot them.  We argue with people we don\'t know all the time.  In stores, shopping malls, at parks.  You don\'t have to know someone to disagree or argue with them; anymore than you know someone you strike up a conversation with while standing around waiting in line.  \n\nWhy would someone just shoot you over an argument?  No I may not understand why some idiot just shot me over a discussion!! \n\nToo many armed idiots are running around Alaska.  While too many unarmed sofa chat patrol people are running around as well; except what they seem to be unarmed with is a brain!  \n\nThe high level of increased violence, not just gun violence, hell violence in general and not just in Anchorage but in all of Alaska, should be every citizens concern. It\'s not our job to scrutinize the victim!  We should be figuring out how to prevent there being a victim.',
#   'target_logits': array([[0.00264332, 0.99735665]], dtype=float32),
#   'concept_logits': array([[0.9020435 , 0.16542749, 0.73651254, 0.99248683, 0.9192955 ]],
#         dtype=float32),
#   'concept_gradient': array([[0.04264687, 0.04850687, 0.04827208, 0.03741225, 0.05686238]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 1, 1, 1]])},
#  {'sentence': 'Darn.  And here I thought Toronto would displace Vancouver as the least affordable city in North America to purchase a house vis a vis income.  And one of the top three cities in the world.\n\nThe ranking must be a good thing, right?  Vancouver has been at the top for a few years, and nary a word of concern from the Federal government.',
#   'target_logits': array([[0.05309438, 0.94690555]], dtype=float32),
#   'concept_logits': array([[0.92739564, 0.0504914 , 0.17805108, 0.86307234, 0.04733818]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.09392089, -0.01002347,  0.00788235,  0.09920634, -0.03016166]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'You are equating a Trump hat with a KKK uniform???  Are you crazy?',
#   'target_logits': array([[0.01271227, 0.98728776]], dtype=float32),
#   'concept_logits': array([[0.43607366, 0.06872929, 0.66574925, 0.96477115, 0.11327884]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.04079456, -0.00856807,  0.06486283,  0.16419078, -0.00681878]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': "Not any one, and precisely none of the Trump family, or any of their hangers ons should have nothing to say about this unless it's to profusely apologize for enabling it.",
#   'target_logits': array([[0.8548851 , 0.14511485]], dtype=float32),
#   'concept_logits': array([[0.03130768, 0.01602527, 0.0686672 , 0.46707806, 0.03311413]],
#         dtype=float32),
#   'concept_gradient': array([[-0.15220635, -0.12698765, -0.11189065, -0.08448598, -0.09501842]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "He is a moron so one can see why. But that doesn't change anything.",
#   'target_logits': array([[0.00188007, 0.9981199 ]], dtype=float32),
#   'concept_logits': array([[0.97895825, 0.17256539, 0.45535046, 0.9967098 , 0.16532823]],
#         dtype=float32),
#   'concept_gradient': array([[0.05011189, 0.06473322, 0.06198953, 0.05829583, 0.09993998]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 1]])},
#  {'sentence': 'Its acceptable to me to drag out drama queens who wont listen to simple instructions on a private plane. I would have drop kicked him out the door',
#   'target_logits': array([[0.10316005, 0.89684   ]], dtype=float32),
#   'concept_logits': array([[0.08209786, 0.06320096, 0.20900033, 0.57138336, 0.82093316]],
#         dtype=float32),
#   'concept_gradient': array([[-0.00065676, -0.01065726,  0.00783107,  0.05922243,  0.0931197 ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 1, 0, 1, 1]])},
#  {'sentence': '"...The dignity of all people... which we are born with."\n\nUntil the Church hierarchy starts recognizing and acting like the dignity of women, gays, transgendered, remarried, laity, etc., is as real and matters as much as that of your basic white-bread straight male cleric, these words are sanctimonious hypocrisy.',
#   'target_logits': array([[0.00557124, 0.99442875]], dtype=float32),
#   'concept_logits': array([[0.14880235, 0.21049525, 0.9460724 , 0.86201   , 0.04579844]],
#         dtype=float32),
#   'concept_gradient': array([[0.02288383, 0.01996045, 0.11978291, 0.08957746, 0.0002395 ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 1]])},
#  {'sentence': "The wonders of diet and exercise have been touted as cures for obesity, depression, adhd, add, diabetes, cancer prevention, you name it. Good for you for researching. This story is about a six-year-old's struggle with and coping with diabetes. Atta boy, Oliver. What a champ, Oliver!! I wish you health and prosperity.",
#   'target_logits': array([[0.99509794, 0.00490205]], dtype=float32),
#   'concept_logits': array([[0.01825666, 0.01427971, 0.02952956, 0.11708578, 0.01878627]],
#         dtype=float32),
#   'concept_gradient': array([[-0.2648288 , -0.18915074, -0.2285494 , -0.17178206, -0.22655462]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "Good idea. It's would work. Just don't jack it up to high for budget travelers.",
#   'target_logits': array([[0.98832357, 0.01167644]], dtype=float32),
#   'concept_logits': array([[0.0250895 , 0.00714908, 0.01282384, 0.1395049 , 0.02174322]],
#         dtype=float32),
#   'concept_gradient': array([[-0.25638935, -0.3032839 , -0.39393798, -0.18217632, -0.23796962]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'In other news the Minister of Finance woke up from his sleep. \n\nIncredible ineptitude!',
#   'target_logits': array([[0.01027987, 0.98972005]], dtype=float32),
#   'concept_logits': array([[0.36914477, 0.06672093, 0.1740009 , 0.96820515, 0.07868326]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.03156563, -0.00449444,  0.01078735,  0.14996111, -0.00440153]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[0, 0, 0, 1, 0]])},
#  {'sentence': '"Having campaigned on a promise to "end welfare as we know it," Bill Clinton, the darling of the Democratic Leadership Council, signed the Personal Responsibility and Work Opportunity Reconciliation Act into law in 1996.\n\nThough Clinton\'s embrace of a reactionary policy sparked sharp protests from activists, in the years following the implementation of welfare reform, its impact was widely celebrated. In conservative corners, analysts applauded the fact that people were being booted off public assistance in droves....\n\nThey were not alone—Democrats, too, were eager to declare victory. Bill Clinton himself, in a New York Times op-ed that same year, cheered the destruction of "a system that had led to intergenerational dependency." Two years later, during her run for the presidency, Hillary Clinton also touted the law\'s effects."\n\nhttp://www.commondreams.org/views/2016/08/29/punishing-poor-welfare-reform-and-its-democratic-apologists',
#   'target_logits': array([[0.9975865 , 0.00241356]], dtype=float32),
#   'concept_logits': array([[0.0180305 , 0.01368034, 0.05089074, 0.10514764, 0.03931407]],
#         dtype=float32),
#   'concept_gradient': array([[-0.11007393, -0.04699396, -0.06248373, -0.09441251, -0.00793363]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Hahahahaha Sadie, do you think before you speak... ever? Is Pierre de Vos also an idiot? You must be quite a superior being. I bow to you, oh great one!',
#   'target_logits': array([[0.00170481, 0.99829525]], dtype=float32),
#   'concept_logits': array([[0.99112505, 0.21948941, 0.6627688 , 0.9975897 , 0.27663568]],
#         dtype=float32),
#   'concept_gradient': array([[0.04504916, 0.05585385, 0.05280545, 0.02836677, 0.0808858 ]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': 'Trump is a racist!\nTrump is  insecure!\nTrump is hitler!\nTrump is a xenophobe!\nTrump is psychotic!\nNeo-nazis in the white house!\n\nAll synonyms for "I\'ve just been hosed in this argument and need to fill the box with squid ink."',
#   'target_logits': array([[0.00280307, 0.9971969 ]], dtype=float32),
#   'concept_logits': array([[0.9299209 , 0.47602177, 0.981795  , 0.99605334, 0.86549056]],
#         dtype=float32),
#   'concept_gradient': array([[0.0444839 , 0.03549433, 0.05708157, 0.04319234, 0.04836911]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 0, 1, 1]])},
#  {'sentence': "If you take into consideration 'glass half empty' analogy......\nIvanka provided them with much needed jobs to buy goods to sustain life in the big city.........\n\nAnother ploy that they used on Martha Stewart and other well-known celebrities to produce their products overseas.",
#   'target_logits': array([[0.99791116, 0.00208879]], dtype=float32),
#   'concept_logits': array([[0.01265129, 0.01036986, 0.03628207, 0.09818653, 0.01674386]],
#         dtype=float32),
#   'concept_gradient': array([[-0.1681395 , -0.10011376, -0.09662522, -0.10475891, -0.08587968]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Yes, and in exchange, Iran could demolish Ankara, Riyadh, or Tel Aviv, anyone close by who allies itself to the US or provides a staging area for an attack. Trump is an egomaniacal lunatic and imagines that he can trash international treaties without consulting Congress, much less vital allies. This behavior is not likely to be tolerated much longer either by the American public or American allies.',
#   'target_logits': array([[0.01495529, 0.98504466]], dtype=float32),
#   'concept_logits': array([[0.24785937, 0.02775685, 0.51225716, 0.93522453, 0.41389564]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.01795441, -0.05926643,  0.04495984,  0.15901439,  0.05088163]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 0, 1, 0]])},
#  {'sentence': 'Or buy a one way ticket...',
#   'target_logits': array([[0.99370015, 0.00629985]], dtype=float32),
#   'concept_logits': array([[0.01295139, 0.00760179, 0.01388593, 0.02293216, 0.02354367]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.03470971,  0.09773006,  0.07777189, -0.01095056,  0.11456692]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': "I've worked with many at the bank and it was always a positive customer caring experience.",
#   'target_logits': array([[0.998359  , 0.00164091]], dtype=float32),
#   'concept_logits': array([[0.01052042, 0.0088478 , 0.01545873, 0.01328648, 0.01385209]],
#         dtype=float32),
#   'concept_gradient': array([[-0.04130545,  0.02366371, -0.00761145, -0.08638229,  0.06517708]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'This is assinine.  Whatever happened to the best person for the job?  I wish our fool of a Prime Minister would just worry about running the company.  I would prefer there were jobs in ths country for my daughters to get, than worrying about legislating that they are gender equal.  Its the economy, stupid.',
#   'target_logits': array([[0.00177902, 0.998221  ]], dtype=float32),
#   'concept_logits': array([[0.9897451 , 0.6041782 , 0.79959595, 0.9973641 , 0.44611427]],
#         dtype=float32),
#   'concept_gradient': array([[ 0.03008451,  0.03176646,  0.04076474, -0.02111031,  0.05303325]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 0, 0, 1, 0]])},
#  {'sentence': 'Nope, most of us - most Canadians - just thought harper was a drain on Canada. We were right.',
#   'target_logits': array([[0.5800147 , 0.41998526]], dtype=float32),
#   'concept_logits': array([[0.14633414, 0.04266248, 0.60655594, 0.6764781 , 0.07772972]],
#         dtype=float32),
#   'concept_gradient': array([[-0.06605612, -0.05026493, -0.05810224, -0.07292838, -0.0365309 ]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Also I have a question about this...\n\n" but pay no attention to that. We all know those deplorable rural conservatives should have no voice in running the country. We should listen to our betters in the cities and just meekly accept whatever destruction comes our way because they know so much better than we do about how we should live our lives and making our livings."\n\nWhy would you even type that? You are trolling or just being mean to those around you with different ideas. You are straight up saying you would silence some voices to hear your own. This is not how America works and it is not how most people I know that call themselves Liberal act, so maybe you could stop with supposition and stay honest reason for what you believe.',
#   'target_logits': array([[0.78135216, 0.2186478 ]], dtype=float32),
#   'concept_logits': array([[0.05171972, 0.01558898, 0.2126138 , 0.63443136, 0.04837498]],
#         dtype=float32),
#   'concept_gradient': array([[-0.13388921, -0.13244584, -0.08659023, -0.07609502, -0.08759571]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  {'sentence': 'Virtually all terrorist acts have been comitted by suni moslems, soooo. Trumpy better get his facts straight unless he want to be seen as the uninformed lunatic he is.',
#   'target_logits': array([[0.00630932, 0.9936907 ]], dtype=float32),
#   'concept_logits': array([[0.5801524 , 0.07220355, 0.7448311 , 0.9824594 , 0.18389568]],
#         dtype=float32),
#   'concept_gradient': array([[0.05018374, 0.0027483 , 0.07048144, 0.17259046, 0.02115253]],
#         dtype=float32),
#   'label': 1,
#   'concept_label': array([[1, 1, 0, 1, 1]])},
#  {'sentence': 'You are using words the meaning of which you don\'t understand, statutorily or under the common law.  Larson, properly under either, attempted to do his duty as a citizen by merely following Tallman to assist in his arrest and was assaulted multiple times without striking back. Only after the third incident did he present a weapon in an attempt to -deter- another assault. Tallman then deliberately chose to attempt to assault an armed, older man rather than using his youth and greater physical ability to flee and was justifiably shot. There\'s nothing "vigilante" in that fact set.',
#   'target_logits': array([[0.97484404, 0.02515591]], dtype=float32),
#   'concept_logits': array([[0.03404778, 0.03065761, 0.06671507, 0.18072054, 0.4822193 ]],
#         dtype=float32),
#   'concept_gradient': array([[-0.20662527, -0.13911085, -0.18431777, -0.16619295, -0.01015313]],
#         dtype=float32),
#   'label': 0,
#   'concept_label': array([[0, 0, 0, 0, 0]])},
#  ...]

# %%
pd.set_option('display.max_colwidth', None)
df_results.sample(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           sentence  \
# 176                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         All that makes me think he's a horrible, arrogant, sleazy, weasel, crook of a Republican. But like Hilary, he's less worse than Trump.
# 843   Williams and Holleman, This is the path to social promotion. The mean reading level of Anchorage high school graduates is seventh grade.  For mathematics it is sixth grade. The UA system spends an inordinate amount of time and money on remedial education because our high school graduates are not prepared for college work.  I am not particularly blaming the teachers, but the system is not working.  Most of that failure rests with the parents and there is little the system can do to fix that. If our public school system were a business it would have been forced to shut down decades ago. So instead of tinkering with standardized graduation testing let's improve results for those that are capable and motivated.
# 1049                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Loser.
# 127                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 So hypocritical. The US is and has been the number one meddler in other countries elections and governments.\nWhat's good for the goose is apparently not good for the gander.
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I have yet to see a woman on a roof stripping shingles. Even carrying and nailing shingles. I have never seen a woman troweling concrete or working on a concrete crew. This equal rights foolishness has gone overboard.
#
#                     target_logits  \
# 176   [[0.0034543686, 0.9965456]]
# 843   [[0.9984145, 0.0015855236]]
# 1049  [[0.014992549, 0.98500746]]
# 127   [[0.012243824, 0.98775613]]
# 46     [[0.019861124, 0.9801389]]
#
#                                                         concept_logits  \
# 176        [[0.8831279, 0.34724164, 0.8705504, 0.9948782, 0.21210144]]
# 843   [[0.012940977, 0.013660851, 0.032178275, 0.13195023, 0.0193337]]
# 1049    [[0.62520665, 0.23438062, 0.14596039, 0.93952864, 0.12467685]]
# 127     [[0.30464816, 0.030655624, 0.41605493, 0.9697194, 0.04975498]]
# 46      [[0.24639589, 0.036675192, 0.5365454, 0.91647136, 0.07402957]]
#
#                                                             concept_gradient  \
# 176          [[0.05465725, 0.037437785, 0.05967429, 0.10609473, 0.06470841]]
# 843     [[-0.18123941, -0.09661099, -0.11829409, -0.098931596, -0.09335074]]
# 1049         [[0.04952069, 0.04434961, 0.069276474, 0.07471935, 0.06861603]]
# 127      [[0.0304129, -0.0025111604, 0.031075269, 0.12211521, 0.0048611513]]
# 46    [[0.028623523, -0.005248331, 0.041953776, 0.09727327, -0.00037343305]]
#
#       label      concept_label
# 176       1  [[1, 0, 1, 1, 1]]
# 843       0  [[0, 0, 0, 0, 0]]
# 1049      1  [[1, 0, 0, 1, 0]]
# 127       1  [[0, 0, 0, 1, 0]]
# 46        1  [[0, 0, 0, 1, 1]]

# %%
df_results.shape
# Out:
# (232, 6)

# %%
import torch
from sklearn.metrics import accuracy_score
from tqdm import tqdm

# Initialize lists to store predictions and true labels for each concept
concept_predictions = [[] for _ in range(5)]
concept_true_labels = [[] for _ in range(5)]

for batch in tqdm(x2y_dl_test, leave=True):
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    labels = batch['toxicity'].to(device)
    concept_labels = batch['concept_labels'].to(device)
    
    # Compute logits for concept model
    concept_logits = x2c_model(input_ids, attention_mask=attention_mask)
    
    # Apply sigmoid to get probabilities
    concept_probs = torch.sigmoid(concept_logits)
    
    # Convert probabilities to binary predictions (0 or 1)
    concept_preds = (concept_probs > 0.5).int()
    
    # Store predictions and true labels for each concept
    for i in range(5):
        concept_predictions[i].extend(concept_preds[:, i].cpu().numpy())
        concept_true_labels[i].extend(concept_labels[:, i].cpu().numpy())

# Compute accuracy for each concept
concept_accuracies = []
for i in range(5):
    accuracy = accuracy_score(concept_true_labels[i], concept_predictions[i])
    concept_accuracies.append(accuracy)

# Print accuracies for each concept
for i, accuracy in enumerate(concept_accuracies):
    print(f"Concept {i+1} Accuracy: {accuracy:.4f}")
# Out:
# 100%|██████████| 1250/1250 [02:29<00:00,  8.36it/s]
# Concept 1 Accuracy: 0.8894
# Concept 2 Accuracy: 0.8424
# Concept 3 Accuracy: 0.7192
# Concept 4 Accuracy: 0.9420
# Concept 5 Accuracy: 0.7536

# %%
from sklearn.metrics import f1_score
concept_f1 = []
for i in range(5):
    accuracy = f1_score(concept_true_labels[i], concept_predictions[i])
    concept_f1.append(accuracy)

# Print accuracies for each concept
for i, accuracy in enumerate(concept_f1):
    print(f"Concept {i+1} F1: {accuracy:.4f}")
# Out:
# Concept 1 F1: 0.8395
# Concept 2 F1: 0.3226
# Concept 3 F1: 0.3728
# Concept 4 F1: 0.9240
# Concept 5 F1: 0.3827
